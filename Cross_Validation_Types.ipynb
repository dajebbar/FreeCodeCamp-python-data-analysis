# %% [markdown]
# <a href="https://colab.research.google.com/github/dajebbar/FreeCodeCamp-python-data-analysis/blob/main/Cross_Validation_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Types of cross validation Techniques

# %% [markdown]
# ## 1 - Cross Validation
# ## 2 - Why Cross validation is important
# ## 3 - Different types of cross validation techniques
# - simple cross validation
# - leave-one-out cross validation
# - K fold cross validation
# - stratified k fold cross validations

# %% [markdown]
# ## 1 - Cross Validation
#
# ![Capture dՎcran de 2022-03-14 09-15-47.png](data:image/png;base64,...)

# %% [markdown]
# ## 2 - Why Cross validation is important
# ![Capture dՎcran de 2022-03-14 09-27-15.png](data:image/png;base64,...)

# %% [markdown]
# ## 3 - Different types of cross validation techniques
# - simple cross validation
# ![Capture dՎcran de 2022-03-14 09-34-08.png](data:image/png;base64,...)
# ![Capture dՎcran de 2022-03-14 09-36-16.png](data:image/png;base64,...)

# %% [markdown]
# - leave-one-out cross validation![Capture dՎcran de 2022-03-14 09-40-40.png](data:image/png;base64,...)

# %% [markdown]
# - K fold cross validation
# ![Capture dՎcran de 2022-03-14 09-48-46.png](data:image/png;base64,...)

# %% [markdown]
# Pros:
# - The model has low bias
# - Low time complexity
#
# Cons:
# - Not suitable for an imbalanced dataset

# %% [markdown]
# - stratified k fold cross validations
# ![Capture dՎcran de 2022-03-14 10-04-56.png](data:image/png;base64,...)
